# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
credits = pd.read_csv('tmdb_5000_credits.csv', sep=',')
movies = pd.read_csv('tmdb_5000_movies.csv', sep=',')
mergeCM = pd.merge(credits, movies, on ='movie_id')
print(mergeCM[:100])
mergeCM.describe()
# Out:
#     movie_id                                      title_x  \
# 0      19995                                       Avatar
# 1        285     Pirates of the Caribbean: At World's End
# 2     206647                                      Spectre
# 3      49026                        The Dark Knight Rises
# 4      49529                                  John Carter
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# ...

# %%
# %matplotlib inline
mergeCM.hist(figsize = (15,20), bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd4366741d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd436b9a160>]], dtype=object)

# %%
x = pd.DataFrame(movies, columns =['budget'])
y = pd.DataFrame(movies, columns =['popularity'])


plt.scatter(x,y)
plt.show()

# %%
credits.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'movie_id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6e74fa5fa604> in <module>()
# ----> 1 ara_df = pd.DataFrame.from_csv(movies)
#       2
#       3 ara_df[:20].plot.bar()
#
# NameError: name 'pd' is not defined
